# %% [markdown]
# **[OFE-01]** 필요한 모듈을 임포트한다.

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import cPickle as pickle
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-51e29875584e> in <module>
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 import cPickle as pickle
#
# ModuleNotFoundError: No module named 'cPickle'

# %%
# !ls -la
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Oct 28 16:30 .
# drwxr-xr-x 1 root root 4096 Nov  3 21:12 ..
# drwxr-xr-x 1 root root 4096 Oct 28 16:30 .config
# drwxr-xr-x 1 root root 4096 Oct 28 16:30 sample_data

# %% [markdown]
# [OFE-01] file을 upload 하는 코드  by Yoo-Joo

# %%
from google.colab import files
uploaded = files.upload()  # 파일 업로드 기능 실행

for fn in uploaded.keys():  # 업로드된 파일 정보 출력
   print('User uploaded file "{name}" with length {length} bytes'.format(
           name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-ac6e8502-64df-477c-a0fc-f4311e01a799" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ac6e8502-64df-477c-a0fc-f4311e01a799">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 09_1_ORENIST.data to 09_1_ORENIST.data
# User uploaded file "09_1_ORENIST.data" with length 2150248 bytes

# %%
# !ls -la
# Out:
# total 2116
# drwxr-xr-x 1 root root    4096 Nov  3 21:17 .
# drwxr-xr-x 1 root root    4096 Nov  3 21:12 ..
# -rw-r--r-- 1 root root 2150248 Nov  3 21:17 09_1_ORENIST.data
# drwxr-xr-x 1 root root    4096 Oct 28 16:30 .config
# drwxr-xr-x 1 root root    4096 Oct 28 16:30 sample_data

# %% [markdown]
# **[OFE-02]** 데이터 파일 'ORENIST.data'에서 이미지와 라벨 데이터를 읽어들인다.

# %%
with open('09_1_ORENIST.data', 'rb') as file:
    images, labels = pickle.load(file)

# %% [markdown]
# **[OFE-03]** 이미지 데이터 샘플을 출력한다.

# %%
fig = plt.figure(figsize=(10,5))
for i in range(90):
    subplot = fig.add_subplot(9, 10, i+1)
    subplot.set_xticks([])
    subplot.set_yticks([])
    subplot.set_title('%d' % np.argmax(labels[i]))
    subplot.imshow(images[i].reshape(28,28), vmin=0, vmax=1,
                   cmap=plt.cm.gray_r, interpolation='nearest')

# %% [markdown]
# **[OFE-04]** 필터 정보를 저장한 다차원 리스트를 만드는 함수를 준비한다.

# %%
def edge_filter():
    filter0 = np.array(
            [[ 2, 1, 0,-1,-2],
             [ 3, 2, 0,-2,-3],
             [ 4, 3, 0,-3,-4],
             [ 3, 2, 0,-2,-3],
             [ 2, 1, 0,-1,-2]]) / 23.0
    filter1 = np.array(
            [[ 2, 3, 4, 3, 2],
             [ 1, 2, 3, 2, 1],
             [ 0, 0, 0, 0, 0],
             [-1,-2,-3,-2,-1],
             [-2,-3,-4,-3,-2]]) / 23.0
    
    filter_array = np.zeros([5,5,1,2])
    filter_array[:,:,0,0] = filter0
    filter_array[:,:,0,1] = filter1

    return tf.constant(filter_array, dtype=tf.float32)

# %% [markdown]
# **[OFE-05]** 이미지 데이터에 필터를 적용하는 계산식을 준비한다.

# %%
x = tf.placeholder(tf.float32, [None, 784])  # 28 x 28 = 784
x_image = tf.reshape(x, [-1,28,28,1])

W_conv = edge_filter()
h_conv = tf.abs(tf.nn.conv2d(x_image, W_conv,
                             strides=[1,1,1,1], padding='SAME'))
h_conv_cutoff = tf.nn.relu(h_conv-0.2)

h_pool =tf.nn.max_pool(h_conv_cutoff, ksize=[1,2,2,1],
                       strides=[1,2,2,1], padding='SAME')

# %% [markdown]
# **[OFE-06]** 세션을 준비하고 Variable을 초기화한다.

# %%
sess = tf.InteractiveSession()
sess.run(tf.global_variables_initializer())

# %% [markdown]
# **[OFE-07]** 최초 9개의 이미지 데이터에 대해 합성곱 필터를 적용한 결과를 계산한다.

# %%
filter_vals, conv_vals = sess.run([W_conv, h_conv_cutoff],
                                  feed_dict={x:images[:9]})

# %% [markdown]
# **[OFE-08]** 얻어진 결과를 이미지로 출력한다.
#
# 여기서는 원본 이미지와 두 종류의 필터를 적용한 결과를 각각 출력하고 있다.
#
# 왼쪽은 적용한 필터를 이미지화한 것이다.

# %%
fig = plt.figure(figsize=(10,3))

for i in range(2):
    subplot = fig.add_subplot(3, 10, 10*(i+1)+1)
    subplot.set_xticks([])
    subplot.set_yticks([])
    subplot.imshow(filter_vals[:,:,0,i],
                   cmap=plt.cm.gray_r, interpolation='nearest')

v_max = np.max(conv_vals)

for i in range(9):
    subplot = fig.add_subplot(3, 10, i+2)
    subplot.set_xticks([])
    subplot.set_yticks([])
    subplot.set_title('%d' % np.argmax(labels[i]))
    subplot.imshow(images[i].reshape((28,28)), vmin=0, vmax=1,
                   cmap=plt.cm.gray_r, interpolation='nearest')
    
    subplot = fig.add_subplot(3, 10, 10+i+2)
    subplot.set_xticks([])
    subplot.set_yticks([])
    subplot.imshow(conv_vals[i,:,:,0], vmin=0, vmax=v_max,
                   cmap=plt.cm.gray_r, interpolation='nearest')
    
    subplot = fig.add_subplot(3, 10, 20+i+2)
    subplot.set_xticks([])
    subplot.set_yticks([])
    subplot.imshow(conv_vals[i,:,:,1], vmin=0, vmax=v_max,
                   cmap=plt.cm.gray_r, interpolation='nearest')

# %% [markdown]
# **[OFE-09]** 필터 적용 후에 풀링 계층을 적용한 결과를 얻는다.

# %%
pool_vals = sess.run(h_pool, feed_dict={x:images[:9]})

# %% [markdown]
# **[OFE-10]** 얻어진 결과를 이미지로 출력한다.

# %%
fig = plt.figure(figsize=(10,3))

for i in range(2):
    subplot = fig.add_subplot(3, 10, 10*(i+1)+1)
    subplot.set_xticks([])
    subplot.set_yticks([])
    subplot.imshow(filter_vals[:,:,0,i],
                   cmap=plt.cm.gray_r, interpolation='nearest')

v_max = np.max(pool_vals)

for i in range(9):
    subplot = fig.add_subplot(3, 10, i+2)
    subplot.set_xticks([])
    subplot.set_yticks([])
    subplot.set_title('%d' % np.argmax(labels[i]))
    subplot.imshow(images[i].reshape((28,28)), vmin=0, vmax=1,
                   cmap=plt.cm.gray_r, interpolation='nearest')
    
    subplot = fig.add_subplot(3, 10, 10+i+2)
    subplot.set_xticks([])
    subplot.set_yticks([])
    subplot.imshow(pool_vals[i,:,:,0], vmin=0, vmax=v_max,
                   cmap=plt.cm.gray_r, interpolation='nearest')
    
    subplot = fig.add_subplot(3, 10, 20+i+2)
    subplot.set_xticks([])
    subplot.set_yticks([])
    subplot.imshow(pool_vals[i,:,:,1], vmin=0, vmax=v_max,
                   cmap=plt.cm.gray_r, interpolation='nearest')
