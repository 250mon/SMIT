# %%
import pandas as pd
import lxml

# %%
tables = pd.read_html('https://en.wikipedia.org/wiki/Leadership_approval_opinion_polling_for_the_next_United_Kingdom_general_election')

# %%
polls_2021, polls_2020 = tables[1:3]

# %%
polls_2021.head(5)
# Out:
#   Date(s)conducted      Pollster/client Sample size          Questionwording  \
#   Date(s)conducted      Pollster/client Sample size          Questionwording
# 0           27 Sep  Redfield and Wilton        2000       Approve/Disapprove
# 1        17–23 Sep           Ipsos MORI        1008   Satisfied/Dissatisfied
# 2        21–22 Sep            Survation        1060  Favourable/Unfavourable
# 3           20 Sep  Redfield and Wilton        2000       Approve/Disapprove
# 4        16–17 Sep              Opinium        2000       Approve/Disapprove
#
#              Approve         Disapprove            Neither Don't know  \
#   Unnamed: 4_level_1 Unnamed: 5_level_1 Unnamed: 6_level_1 Don't know
# 0                36%                42%                19%         2%
# 1                39%                51%                NaN         9%
# 2                39%                44%                16%         2%
# 3                37%                42%                20%         2%
# ...

# %%
polls_2020.head(5)
# Out:
#   Date(s)conducted Pollster/client Sample size          Questionwording  \
#   Date(s)conducted Pollster/client Sample size          Questionwording
# 0        26–30 Dec       Deltapoll        1608               Well/Badly
# 1           30 Dec          YouGov        1633               Well/Badly
# 2        17–18 Dec          YouGov         TBA  Favourable/Unfavourable
# 3        16–17 Dec         Opinium        2001       Approve/Disapprove
# 4        11–13 Dec   SavantaComRes        2026  Favourable/Unfavourable
#
#              Approve         Disapprove            Neither Don't know  \
#   Unnamed: 4_level_1 Unnamed: 5_level_1 Unnamed: 6_level_1 Don't know
# 0                46%                49%                NaN         5%
# 1                37%                56%                NaN         7%
# 2                35%                56%                NaN         9%
# 3                38%                44%                NaN        19%
# ...

# %%
polls_2021.iloc[:, 1].value_counts()
# Out:
# Redfield and Wilton         39
# Opinium                     21
# YouGov                      17
# Survation                   16
# Ipsos MORI                  11
# SavantaComRes                8
# Deltapoll                    6
# Panelbase                    3
# BMG                          2
# Number Cruncher Politics     1
# Name: (Pollster/client, Pollster/client), dtype: int64

# %%
polls_2020.iloc[:, 1].value_counts()
# Out:
# Opinium                28
# Redfield and Wilton    24
# YouGov                 23
# Survation              11
# Ipsos MORI             11
# Deltapoll               8
# SavantaComRes           7
# Name: (Pollster/client, Pollster/client), dtype: int64

# %%
polls_2021.to_hdf('polls.hdf', 'polls_2021')

# %%
polls_2021.to_hdf('polls.hdf', 'polls_2020')

# %%
df_2021 = pd.read_hdf('polls.hdf', 'polls_2021')

# %%
df_2021.head(5)
# Out:
#   Date(s)conducted      Pollster/client Sample size          Questionwording  \
#   Date(s)conducted      Pollster/client Sample size          Questionwording
# 0           27 Sep  Redfield and Wilton        2000       Approve/Disapprove
# 1        17–23 Sep           Ipsos MORI        1008   Satisfied/Dissatisfied
# 2        21–22 Sep            Survation        1060  Favourable/Unfavourable
# 3           20 Sep  Redfield and Wilton        2000       Approve/Disapprove
# 4        16–17 Sep              Opinium        2000       Approve/Disapprove
#
#              Approve         Disapprove            Neither Don't know  \
#   Unnamed: 4_level_1 Unnamed: 5_level_1 Unnamed: 6_level_1 Don't know
# 0                36%                42%                19%         2%
# 1                39%                51%                NaN         9%
# 2                39%                44%                16%         2%
# 3                37%                42%                20%         2%
# ...

# %%
ls
# Out:
# HWs.ipynb  polls.hdf
